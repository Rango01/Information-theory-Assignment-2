# %%
text = open('text.txt', 'r')
text = text.read()
freq = {}
count=len(text)
for i in text:
  freq[i] = freq.get(i,0) + (1/count)
print(freq)
# Out:
# {'L': 0.008665511265164644, 'o': 0.04332755632582321, 'r': 0.041594454072790284, 'e': 0.10225303292894278, 'm': 0.03119584055459271, ' ': 0.1559792027729638, 'I': 0.010398613518197573, 'p': 0.03119584055459271, 's': 0.06759098786828421, 'u': 0.029462738301559783, 'i': 0.05545927209705371, 'l': 0.029462738301559783, 'y': 0.02253032928942807, 'd': 0.027729636048526855, 't': 0.07452339688041593, 'x': 0.0034662045060658577, 'f': 0.010398613518197573, 'h': 0.024263431542460998, 'n': 0.06585788561525129, 'g': 0.019064124783362214, 'a': 0.048526863084921996, '.': 0.006932409012131715, 'b': 0.008665511265164644, "'": 0.0017331022530329288, 'v': 0.008665511265164644, 'c': 0.017331022530329285, '1': 0.0034662045060658577, '5': 0.0017331022530329288, '0': 0.005199306759098786, ',': 0.006932409012131715, 'w': 0.010398613518197573, 'k': 0.0121317157712305, '9': 0.0034662045060658577, '6': 0.0017331022530329288, 'A': 0.0017331022530329288, 'P': 0.0017331022530329288, 'M': 0.0017331022530329288, '8
# ...
